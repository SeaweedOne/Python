# %%
import pandas as pd
import numpy as np
customerData = pd.read_csv("./dataset/customerData.csv")

# %%
#정렬하기

# %%
customerData.columns
# Out:
# Index(['CUSTID', 'AVGPRICE', 'EMI', 'DEVICECOUNT', 'PRODUCTAGE', 'CUSTTYPE'], dtype='object')

# %%
sortKey = ["EMI","AVGPRICE"]

# %%
sortedData = customerData.sort_values(by=sortKey,
                                     ascending = [True,True],
                                     inplace=False) #EMI가 1일떄 오름차순 ,2일떄 오름차순 ~~

# %%
customeerData.reset_index(drop=True, ignore_index=True)

# %%
sortedData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 68   N14862  2390.083736    1            6    1.000000        Early-bird
# 47   I17056  2963.370122    1            3    2.139196      Sleeping-dog
# 140  Y12458  2976.211190    1            3    2.199677      Sleeping-dog
# 73   O13586  2980.229239    1            3    2.038603      Sleeping-dog
# 86   Q16449  3048.308860    1            3    2.369758      Sleeping-dog
# ..      ...          ...  ...          ...         ...               ...
# 107  S17396  3895.200000    3            6    2.055707  Big-Screen-lover
# 40   H16326  3988.935304    3            6    0.900000        Early-bird
# 113  T11473  4165.700000    3            6    1.780674  Big-Screen-lover
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 130  W13404  4296.873743    3            6    1.100000        Early-bird
#
# [150 rows x 6 columns]

# %%
groupKey = ["EMI"]

# %%
customerData.groupby(groupKey)[["AVGPRICE"]].agg("mean")
# Out:
#         AVGPRICE
# EMI
# 1    3119.031810
# 2    3441.429664
# 3    3559.487188

# %%
#컬럼조회하기 
targetColumns = ["CUSTID", "EMI"]
customerDataC = customerData.loc[:, targetColumns] #-전체행을 조회 , 뒤에는 내가 원하는 컬럼 (값으로 사용시 가독성은 좋지만 형상변경시 찾아서 바꿔야함)
cusD = customerData.loc[:, "CUSTID":"EMI"] #컬럼을 이런식으로도 선택 가능하다.
cusD
# Out:
#      CUSTID     AVGPRICE  EMI
# 0    A13566  4273.900000    3
# 1    A14219  3642.441950    2
# 2    A15312  3653.884565    2
# 3    A16605  3713.211107    2
# 4    B10634  3391.074215    2
# ..      ...          ...  ...
# 145  Z13253  3678.800000    2
# 146  Z13534  3662.437527    3
# 147  Z16428  3516.500000    2
# 148  Z16735  3300.100000    2
# 149  Z19835  3326.526183    2
#
# [150 rows x 3 columns]

# %%
customerData.iloc[:,0:3] #->3 포함하지 않음. 인덱스로 사용시 형상 변경이 유연하다는 장점 / 가독성이 떨어진다는 단점을 가지고있다.
# Out:
#      CUSTID     AVGPRICE  EMI
# 0    A13566  4273.900000    3
# 1    A14219  3642.441950    2
# 2    A15312  3653.884565    2
# 3    A16605  3713.211107    2
# 4    B10634  3391.074215    2
# ..      ...          ...  ...
# 145  Z13253  3678.800000    2
# 146  Z13534  3662.437527    3
# 147  Z16428  3516.500000    2
# 148  Z16735  3300.100000    2
# 149  Z19835  3326.526183    2
#
# [150 rows x 3 columns]

# %%
customerDataC2 = customerDataC.copy()

# %%
customerDataC3 = customerDataC  #c3변경시 c까지 변경됨

# %%
customerDataC3.CUSTID = 1
customerDataC
# Out:
#      CUSTID  EMI
# 0         1    3
# 1         1    2
# 2         1    2
# 3         1    2
# 4         1    2
# ..      ...  ...
# 145       1    2
# 146       1    3
# 147       1    2
# 148       1    2
# 149       1    2
#
# [150 rows x 2 columns]

# %%
customerDataC2.CUSTID = 22
customerDataC
# Out:
#      CUSTID  EMI
# 0         2    3
# 1         2    2
# 2         2    2
# 3         2    2
# 4         2    2
# ..      ...  ...
# 145       2    2
# 146       2    3
# 147       2    2
# 148       2    2
# 149       2    2
#
# [150 rows x 2 columns]

# %%
emi3Data = customerData.loc [ customerData.EMI == 3]

# %%
emi3Data
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 27   F17131  3179.708359    3            6    1.100000        Early-bird
# 33   G16437  3787.328898    3            6    1.000000        Early-bird
# 36   G18402  3402.199381    3            6    1.000000        Early-bird
# 40   H16326  3988.935304    3            6    0.900000        Early-bird
# 45   I12899  3018.895637    3            6    0.900000        Early-bird
# 51   J10809  3676.135627    3            6    0.800000        Early-bird
# 52   J15083  2811.265932    3            6    0.900000        Early-bird
# 53   J16445  3041.848186    3            6    0.800000        Early-bird
# 60   L13892  3263.515145    3            6    1.100000        Early-bird
# 67   N13273  3839.694732    3            6    1.100000        Early-bird
# 95   R16364  3592.353540    3            6    0.900000        Early-bird
# ...

# %%
emi3Data.reset_index() #index재설정 기존 인덱스는 index컬럼에 들어가있다.
# Out:
#     index  CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0       0  A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1      27  F17131  3179.708359    3            6    1.100000        Early-bird
# 2      33  G16437  3787.328898    3            6    1.000000        Early-bird
# 3      36  G18402  3402.199381    3            6    1.000000        Early-bird
# 4      40  H16326  3988.935304    3            6    0.900000        Early-bird
# 5      45  I12899  3018.895637    3            6    0.900000        Early-bird
# 6      51  J10809  3676.135627    3            6    0.800000        Early-bird
# 7      52  J15083  2811.265932    3            6    0.900000        Early-bird
# 8      53  J16445  3041.848186    3            6    0.800000        Early-bird
# 9      60  L13892  3263.515145    3            6    1.100000        Early-bird
# 10     67  N13273  3839.694732    3            6    1.100000        Early-bird
# ...

# %%
#(drop = True)로 설정하면 기존 인덱스가 날아가고 새로정의됨
#shift + tab 눌러 replace 확인  replace가 flase면 적용한 값이 저장되지 않음 (조회만.) 그러면 변수에 다시 담아줘야함 a = a.reset_index()처럼
#(drop = True, inplace = True)로 해서 적용하면 기존 변수에 즉시 반영한다.
emi3Data.reset_index(drop = True , inplace = True)
emi3Data
# Out:
#     CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0   A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1   F17131  3179.708359    3            6    1.100000        Early-bird
# 2   G16437  3787.328898    3            6    1.000000        Early-bird
# 3   G18402  3402.199381    3            6    1.000000        Early-bird
# 4   H16326  3988.935304    3            6    0.900000        Early-bird
# 5   I12899  3018.895637    3            6    0.900000        Early-bird
# 6   J10809  3676.135627    3            6    0.800000        Early-bird
# 7   J15083  2811.265932    3            6    0.900000        Early-bird
# 8   J16445  3041.848186    3            6    0.800000        Early-bird
# 9   L13892  3263.515145    3            6    1.100000        Early-bird
# 10  N13273  3839.694732    3            6    1.100000        Early-bird
# 11  R16364  3592.353540    3            6    0.900000        Early-bird
# ...

# %%
#파일 임포트 및 csv파일 변수에 넣어주기
import pandas as pd
import numpy as np
kopo_customerData = pd.read_csv("./dataset/kopo_customerData.csv", encoding="ms949")

# %%
#조회할 컬럼 정의 / 인덱스를 이용해 5줄 불러오기 
targetCol = ["STATENAME","GENDER"]
kopo_customerDataC = kopo_customerData.loc[:4, targetCol]

kopo_customerDataC
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male

# %%
stateNameIndex = kopo_customerData.get_loc("GENDER")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-3ea17856c2dc> in <module>
# ----> 1 stateNameIndex = kopo_customerData.get_loc("GENDER")
#
# C:\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_loc'

# %%
customerData["PRODCUTAGE_NEW"] = np.where( customerData.PRODUCTAGE < 1,1,0 ) #창일때 1 거짓일떄 0

# %%
customerData.loc[ (customerData.PRODUCTAGE < 1 ) &(customerData.PRODCUTAGE_NEW!=1) ]
# Out:
# Empty DataFrame
# Columns: [CUSTID, AVGPRICE, EMI, DEVICECOUNT, PRODUCTAGE, CUSTTYPE, PRODCUTAGE_NEW]
# Index: []

# %%
customerData["PRODCUTAGE_NEW"] = np.where( customerData.PRODUCTAGE < 1,1,\
                                         np.where(customerData.PRODUCTAGE <2, 2, 3))

# %%
#데이터 조작방법 
#1. np.where (복잡한 로직에는 힘들어진다)
#2. 함수활용 (복잡한 로직에도 강하다)
#3. loc함수 활용 (가독성이 뛰어나나 속도가 떨어짐)
#4. map 함수 사용(머신러닝에서 많이 사용됨)

# %%
#함수활용

# %%
#함수정의  
# 1미만인 경우 : 1
# 2미만 2
# 그외 3

# %%
def valueClustering(inValue):
    # inValue = 2
    outValue = inValue
    
    if inValue < 1:
        outValue = 1
    elif inValue < 2:
        outValue = 2
    else:
        outValue = 3
    return outValue

# %%
customerData["PRODUCTAGE_NEW"] = customerData.PRODUCTAGE.apply(valueClustering)

# %%
customerData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2            6    0.900000        Early-bird
# 4    B10634  3391.074215    2            4    2.453656      Sleeping-dog
# ..      ...          ...  ...          ...         ...               ...
# 145  Z13253  3678.800000    2            5    2.463670  Big-Screen-lover
# 146  Z13534  3662.437527    3            6    0.900000        Early-bird
# 147  Z16428  3516.500000    2            5    2.371301  Big-Screen-lover
# 148  Z16735  3300.100000    2            5    1.704942  Big-Screen-lover
# 149  Z19835  3326.526183    2            6    1.200000        Early-bird
#
#      PRODCUTAGE_NEW  PRODUCTAGE_NEW    NEWCOL
# ...

# %%
customerData.loc[ customerData.PRODUCTAGE < 1, "PRODCUTAGE_NEW"] = 1

# %%
customerData.loc [ (customerData.PRODUCTAGE<1) & (custo)]

# %%
featuresData = pd.read_csv("./dataset/feature_regression_example.csv")

# %%
featuresData
# Out:
#            REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
# ..              ...          ...          ...       ...       ...   ...   ...
# 100  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016    48
# 101  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016    49
# 102  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016    50
# 103  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016    51
# 104  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
#
# ...

# %%
ynMap = {"Y":1,"N":0}

# %%
featuresData["HOLIDAY_NEW"] = featuresData.HOLIDAY.map(ynMap)

# %%
featuresData
# Out:
#            REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
# ..              ...          ...          ...       ...       ...   ...   ...
# 100  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016    48
# 101  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016    49
# 102  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016    50
# 103  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016    51
# 104  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
#
# ...

# %%
def ynDecimalCovert(inValue):
    if invalue == "Y": outValue = 1
    else: outValue = 0
    return outValue

# %%
customerData["NEWCOL"]=customerData.CUSTID.str.lower() +"_"+ customerData.EMI.astype(str) #컬럼이 문자열이라도 문자열과 데이터프레임은 다르기때문에 lower같은 문자열 함수를 쓰려면 .str을 꼭 붙여줘야한다.

# %%
customerData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2            6    0.900000        Early-bird
# 4    B10634  3391.074215    2            4    2.453656      Sleeping-dog
# ..      ...          ...  ...          ...         ...               ...
# 145  Z13253  3678.800000    2            5    2.463670  Big-Screen-lover
# 146  Z13534  3662.437527    3            6    0.900000        Early-bird
# 147  Z16428  3516.500000    2            5    2.371301  Big-Screen-lover
# 148  Z16735  3300.100000    2            5    1.704942  Big-Screen-lover
# 149  Z19835  3326.526183    2            6    1.200000        Early-bird
#
#      PRODCUTAGE_NEW  PRODUCTAGE_NEW    NEWCOL
# ...

# %%
컬럼이 20개를 넘지 않도록 (피치못할 상황에서는 예외)
파이썬 정렬 sort_values
정렬시 ignore_index = false (기본) true (정렬하고나서 기존인덱스 무시하고 인덱스 새로 부여 )
inplace = flase = false ->바로반영 x true->기존 데이터에 바로 반영됨

# %%
함수 기본값 정의 방법
# Out:
#   File "<ipython-input-8-c80adc3ea6e8>", line 1
#     함수 기본값 정의 방법
#          ^
# SyntaxError: invalid syntax

# %%
def aaa(invalue=3):
    out = invalue + 2
    return out

# %%
aaa(2)
# Out:
# 4

# %%
aaa()
# Out:
# 5
